# %%
import squarify

# %%
squarify.plot(sizes =[ 40, 30, 5, 25])
# Out:
# <Axes: >

# %% [markdown]
# in Above Graph when we every time rerun the code, we get diffrent colors

# %%
squarify.plot(sizes =[ 40, 30, 5, 25], color=["Red", "Blue", "Yellow", "Green"])
# Out:
# <Axes: >

# %%
squarify.plot(sizes =[ 40, 30, 5, 25], color=["Red", "Blue", "Yellow", "Green"], label=[1, 2, 3, 4])
# Out:
# <Axes: >

# %%
squarify.plot(sizes =[ 40, 30, 5, 25], color=["Red", "Blue", "Yellow", "Green"], label=[1, 2, 3, 4], alpha=.5)    #alpha is used for opacity
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

squarify.plot(
    sizes =[ 40, 30, 5, 25], 
    color=["Red", "Blue", "Yellow", "Green"],
    label=[1, 2, 3, 4],
    alpha=.5
) 

#Removing the Axis values
plt.axis("off")
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %%
branch_type = df.groupby('Branch')['Total Fees'].sum()
branch_type

# %%
pip install squarify

# %%
import squarify

# %%
squarify.plot(branch_type['Total Fees'])
plt.show()
